# %%
import matplotlib.image as img
import matplotlib.pyplot as plt
from transforms import crop_nonzero
img=img.imread(r"ODIR-5K_Training_Dataset\7_left.jpg")
cropped_img=crop_nonzero(img)
plot_img=plt.imshow(cropped_img)
